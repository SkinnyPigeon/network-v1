# %% [markdown]
# # Adding Noise to Perfect Data

# %% [markdown]
# ### Imports

# %%
import random
from typing import List
from statistics import mean, stdev
import pandas as pd
import seaborn as sns
import tensorflow as tf
import matplotlib
import matplotlib.pyplot as plt
from matplotlib import animation, patches
import numpy as np
from tensorflow import keras
from tensorflow.keras.optimizers import Adam
from sklearn import preprocessing
from IPython.display import HTML, Image
from scipy.stats import norm

matplotlib.rcParams["animation.embed_limit"] = 2**128
matplotlib.rcParams["figure.dpi"] = 300

# %% [markdown]
# ### Generating Data

# %%
from random import randint, shuffle

samples = 1000

def generate_random_values():
    return [randint(0,50) * randint(0,50) for _ in range(samples)]

ms = [2 for _ in range(samples)]
xs = generate_random_values()
cs = [50 for _ in range(samples)]

ys = []
for i in range(samples):
    y = ms[i] * xs[i] + cs[i]
    ys.append(y)
noise = [random.randint(0,100) for _ in range(samples)]

data = {
    "ms": ms,
    "xs": xs,
    "cs": cs,
    "noise": noise, 
    "ys": ys
}

df = pd.DataFrame(data=data)
test = df.head(5)
test
# Out:
#    ms    xs  cs  noise    ys
# 0   2   816  50     35  1682
# 1   2   224  50     60   498
# 2   2  1364  50     50  2778
# 3   2   203  50     71   456
# 4   2     0  50     17    50

# %%
columns = ["ms", "xs", "cs", "noise"]
all_columns = columns + ["ys"]
X_train = df[columns]
y_train = df["ys"]

# %% [markdown]
# ### Defining Model

# %%
model = tf.keras.Sequential()
model.add(tf.keras.layers.Dense(units=4, input_shape=[4]))
model.add(tf.keras.layers.Dense(units=1))
model.summary()
opt = Adam(0.01)
model.compile(optimizer=opt, loss="mean_squared_error")
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 4)                 20
#
#  dense_1 (Dense)             (None, 1)                 5
#
# =================================================================
# Total params: 25
# Trainable params: 25
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### Data Structure to Capture Weights During Trianing

# %%
history = {
    "loss": [],
    0: {
        0: [],
        1: [],
        2: [],
        3: []
    },
    1: {
        0: [],
        1: [],
        2: [],
        3: []
    },
    2: {
        0: [],
        1: [],
        2: [],
        3: []
    },
    3: {
        0: [],
        1: [],
        2: [],
        3: []
    }, 
}

# %% [markdown]
# ### Training Model and Capturing Weights

# %%
for epoch in range(1, 501):
    print(f"RUNNING EPOCH {epoch}")
    hist = model.fit(X_train, y_train, epochs=1)
    history["loss"].append(hist.history["loss"])
    all_weights = model.layers[0].get_weights()[0].tolist()
    for weights in range(len(all_weights)):
        for weight in range(len(all_weights[weights])):
            history[weights][weight].append(all_weights[weights][weight])
# Out:
# RUNNING EPOCH 1
# 32/32 [==============================] - 0s 6ms/step - loss: 2266228.2500
# RUNNING EPOCH 2
# 32/32 [==============================] - 0s 5ms/step - loss: 492026.9375
# RUNNING EPOCH 3
# 32/32 [==============================] - 0s 5ms/step - loss: 31616.2422
# RUNNING EPOCH 4
# 32/32 [==============================] - 0s 6ms/step - loss: 15718.8584
# RUNNING EPOCH 5
# 32/32 [==============================] - 0s 5ms/step - loss: 12098.1611
# RUNNING EPOCH 6
# 32/32 [==============================] - 0s 5ms/step - loss: 9520.0596
# RUNNING EPOCH 7
# 32/32 [==============================] - 0s 5ms/step - loss: 7344.8081
# RUNNING EPOCH 8
# 32/32 [==============================] - 0s 5ms/step - loss: 5563.9365
# RUNNING EPOCH 9
# 32/32 [==============================] - 0s 5ms/step - loss: 4138.1782
# RUNNING EPOCH 10
# 32/32 [==============================] - 0s 5ms/step - loss: 16.7094
# RUNNING EPOCH 45
# 32/32 [==============================] - 0s 5ms/step - loss: 14.4852
# RUNNING EPOCH 46
# 32/32 [==============================] - 0s 5ms/step - loss: 12.6338
# RUNNING EPOCH 47
# 32/32 [==============================] - 0s 5ms/step - loss: 10.8980
# RUNNING EPOCH 48
# 32/32 [==============================] - 0s 5ms/step - loss: 9.5296
# RUNNING EPOCH 49
# 32/32 [==============================] - 0s 5ms/step - loss: 8.0773
# RUNNING EPOCH 50
# 32/32 [==============================] - 0s 5ms/step - loss: 6.8920
# RUNNING EPOCH 51
# 32/32 [==============================] - 0s 4ms/step - loss: 5.9339
# RUNNING EPOCH 52
# 32/32 [==============================] - 0s 4ms/step - loss: 5.0251
# RUNNING EPOCH 53
# 32/32 [==============================] - 0s 4ms/step - loss: 4.2426
# RUNNING EPOCH 54
# 32/32 [==============================] - 0s 4ms/step - loss: 3.5988
# RUNNING EPOCH 55
# 32/32 [==============================] - 0s 4ms/step - loss: 3.0374
# RUNNING EPOCH 56
# 32/32 [==============================] - 0s 4ms/step - loss: 2.5488
# RUNNING EPOCH 57
# 32/32 [==============================] - 0s 4ms/step - loss: 2.1541
# RUNNING EPOCH 58
# 32/32 [==============================] - 0s 4ms/step - loss: 1.7682
# RUNNING EPOCH 59
# 32/32 [==============================] - 0s 5ms/step - loss: 1.4647
# RUNNING EPOCH 60
# 32/32 [==============================] - 0s 5ms/step - loss: 1.2139
# RUNNING EPOCH 61
# 32/32 [==============================] - 0s 5ms/step - loss: 1.0011
# RUNNING EPOCH 62
# 32/32 [==============================] - 0s 5ms/step - loss: 0.8297
# RUNNING EPOCH 63
# 32/32 [==============================] - 0s 5ms/step - loss: 0.6732
# RUNNING EPOCH 64
# 32/32 [==============================] - 0s 5ms/step - loss: 0.5452
# RUNNING EPOCH 65
# 32/32 [==============================] - 0s 5ms/step - loss: 0.4428
# RUNNING EPOCH 66
# 32/32 [==============================] - 0s 4ms/step - loss: 0.3566
# RUNNING EPOCH 67
# 32/32 [==============================] - 0s 4ms/step - loss: 0.2985
# RUNNING EPOCH 68
# 32/32 [==============================] - 0s 4ms/step - loss: 0.2308
# RUNNING EPOCH 69
# 32/32 [==============================] - 0s 4ms/step - loss: 0.1917
# RUNNING EPOCH 70
# 32/32 [==============================] - 0s 4ms/step - loss: 0.1470
# RUNNING EPOCH 71
# 32/32 [==============================] - 0s 4ms/step - loss: 0.1161
# RUNNING EPOCH 72
# 32/32 [==============================] - 0s 4ms/step - loss: 0.0917
# RUNNING EPOCH 73
# 32/32 [==============================] - 0s 4ms/step - loss: 0.0716
# RUNNING EPOCH 74
# 32/32 [==============================] - 0s 4ms/step - loss: 0.0559
# RUNNING EPOCH 75
# 32/32 [==============================] - 0s 4ms/step - loss: 0.0440
# RUNNING EPOCH 76
# 32/32 [==============================] - 0s 4ms/step - loss: 0.0345
# RUNNING EPOCH 77
# 32/32 [==============================] - 0s 4ms/step - loss: 0.0272
# RUNNING EPOCH 78
# 32/32 [==============================] - 0s 4ms/step - loss: 0.0200
# RUNNING EPOCH 79
# 32/32 [==============================] - 0s 5ms/step - loss: 0.0152
# RUNNING EPOCH 80
# 32/32 [==============================] - 0s 4ms/step - loss: 0.0117
# RUNNING EPOCH 81
# 32/32 [==============================] - 0s 4ms/step - loss: 0.0088
# RUNNING EPOCH 82
# 32/32 [==============================] - 0s 4ms/step - loss: 0.0066
# RUNNING EPOCH 83
# 32/32 [==============================] - 0s 4ms/step - loss: 0.0049
# RUNNING EPOCH 84
# 32/32 [==============================] - 0s 4ms/step - loss: 0.0036
# RUNNING EPOCH 85
# 32/32 [==============================] - 0s 4ms/step - loss: 0.0027
# RUNNING EPOCH 86
# 32/32 [==============================] - 0s 4ms/step - loss: 0.0020
# RUNNING EPOCH 87
# 32/32 [==============================] - 0s 4ms/step - loss: 0.0015
# RUNNING EPOCH 88
# 32/32 [==============================] - 0s 5ms/step - loss: 0.0011
# RUNNING EPOCH 89
# 32/32 [==============================] - 0s 5ms/step - loss: 7.7478e-04
# RUNNING EPOCH 90
# 32/32 [==============================] - 0s 4ms/step - loss: 5.6146e-04
# RUNNING EPOCH 91
# 32/32 [==============================] - 0s 4ms/step - loss: 3.8794e-04
# RUNNING EPOCH 92
# 32/32 [==============================] - 0s 4ms/step - loss: 2.7764e-04
# RUNNING EPOCH 93
# 32/32 [==============================] - 0s 4ms/step - loss: 1.9535e-04
# RUNNING EPOCH 94
# 32/32 [==============================] - 0s 4ms/step - loss: 1.3808e-04
# RUNNING EPOCH 95
# 32/32 [==============================] - 0s 4ms/step - loss: 9.8518e-05
# RUNNING EPOCH 96
# 32/32 [==============================] - 0s 5ms/step - loss: 6.7587e-05
# RUNNING EPOCH 97
# 32/32 [==============================] - 0s 4ms/step - loss: 4.5860e-05
# RUNNING EPOCH 98
# 32/32 [==============================] - 0s 4ms/step - loss: 3.1046e-05
# RUNNING EPOCH 99
# 32/32 [==============================] - 0s 4ms/step - loss: 2.1454e-05
# RUNNING EPOCH 100
# 32/32 [==============================] - 0s 4ms/step - loss: 1.
# 32/32 [==============================] - 0s 4ms/step - loss: 0.0327
# RUNNING EPOCH 477
# 32/32 [==============================] - 0s 4ms/step - loss: 0.0044
# RUNNING EPOCH 478
# 32/32 [==============================] - 0s 4ms/step - loss: 3.5056e-04
# RUNNING EPOCH 479
# 32/32 [==============================] - 0s 4ms/step - loss: 5.2657e-04
# RUNNING EPOCH 480
# 32/32 [==============================] - 0s 4ms/step - loss: 7.7986e-04
# RUNNING EPOCH 481
# 32/32 [==============================] - 0s 4ms/step - loss: 0.1145
# RUNNING EPOCH 482
# 32/32 [==============================] - 0s 4ms/step - loss: 1.3801
# RUNNING EPOCH 483
# 32/32 [==============================] - 0s 4ms/step - loss: 2.7640
# RUNNING EPOCH 484
# 32/32 [==============================] - 0s 5ms/step - loss: 1.2843
# RUNNING EPOCH 485
# 32/32 [==============================] - 0s 4ms/step - loss: 0.5839
# RUNNING EPOCH 486
# 32/32 [==============================] - 0s 4ms/step - loss: 2.0211
# RUNNING EPOCH 487
# 32/32 [==============================] - 0s 4ms/step - loss: 0.2630
# RUNNING EPOCH 488
# 32/32 [==============================] - 0s 4ms/step - loss: 0.7993
# RUNNING EPOCH 489
# 32/32 [==============================] - 0s 5ms/step - loss: 3.5767
# RUNNING EPOCH 490
# 32/32 [==============================] - 0s 5ms/step - loss: 89.0281
# RUNNING EPOCH 491
# 32/32 [==============================] - 0s 5ms/step - loss: 25.1300
# RUNNING EPOCH 492
# 32/32 [==============================] - 0s 5ms/step - loss: 0.5373
# RUNNING EPOCH 493
# 32/32 [==============================] - 0s 5ms/step - loss: 0.1422
# RUNNING EPOCH 494
# 32/32 [==============================] - 0s 4ms/step - loss: 0.0399
# RUNNING EPOCH 495
# 32/32 [==============================] - 0s 4ms/step - loss: 0.0029
# RUNNING EPOCH 496
# 32/32 [==============================] - 0s 4ms/step - loss: 4.2528e-05
# RUNNING EPOCH 497
# 32/32 [==============================] - 0s 4ms/step - loss: 7.0897e-06
# RUNNING EPOCH 498
# 32/32 [==============================] - 0s 4ms/step - loss: 1.9734e-06
# RUNNING EPOCH 499
# 32/32 [==============================] - 0s 4ms/step - loss: 4.7570e-07
# RUNNING EPOCH 500
# 32/32 [==============================] - 0s 4ms/step - loss: 5.4445e-07

# %% [markdown]
# ### Sense Checking Results

# %%
test["result"] = model.predict(test[columns])
test
# Out:
# 1/1 [==============================] - 0s 51ms/step
# <ipython-input-7-a54c478e00da>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test["result"] = model.predict(test[columns])
#    ms    xs  cs  noise    ys       result
# 0   2   816  50     35  1682  1681.999146
# 1   2   224  50     60   498   497.999634
# 2   2  1364  50     50  2778  2777.998535
# 3   2   203  50     71   456   455.999634
# 4   2     0  50     17    50    49.999874

# %% [markdown]
# ### Colours

# %%
light = "#90CCF4"
darker = "#5DA2D5"
important = "#F3D250"
noise = "#F78888"
other = "#ECECEC"

# %% [markdown]
# ### Animated Bar Graph

# %%
frames = 500
fig, ax = plt.subplots(figsize=(16,8))

# %%
def run(i):
  ax.cla()
  ax.set_xlabel("Input Column and Node Number")
  ax.set_ylabel("Weight")
  ax.set_ylim(-1.5, 1.5)
  m_one = history[0][0][i]
  m_two = history[0][1][i]
  m_three = history[0][2][i]
  m_four = history[0][3][i]
  
  x_one = history[1][0][i]
  x_two = history[1][1][i]
  x_three = history[1][2][i]
  x_four = history[1][3][i]

  c_one = history[2][0][i]
  c_two = history[2][1][i]
  c_three = history[2][2][i]
  c_four = history[2][3][i]

  noise_one = history[3][0][i]
  noise_two = history[3][1][i]
  noise_three = history[3][2][i]
  noise_four = history[3][3][i]
  ax.bar(
    [
      "M1", "M2", "M3", "M4", 
      "X1", "X2", "X3", "X4", 
      "C1", "C2", "C3", "C4", 
      "Noise 1", "Noise 2", "Noise 3", "Noise 4", 
    ],
    [
      m_one, m_two, m_three, m_four,
      x_one, x_two, x_three, x_four,
      c_one, c_two, c_three, c_four,
      noise_two, noise_two, noise_three, noise_four,
    ],
    color=[
      darker, darker, darker, darker,
      important, important, important, important,
      light, light, light, light, 
      noise, noise, noise, noise
    ]
  )

# %%
anim = animation.FuncAnimation(fig, run, frames=frames, interval=50)
HTML(anim.to_html5_video())
# Out:
# <video width="4800" height="2400" controls autoplay loop>
#   <source type="video/mp4" src="...

# %% [markdown]
# ### Useful Data Set

# %%
start_index = 0

m_one = history[0][0][start_index:]
m_two = history[0][1][start_index:]
m_three = history[0][2][start_index:]
m_four = history[0][3][start_index:]

x_one = history[1][0][start_index:]
x_two = history[1][1][start_index:]
x_three = history[1][2][start_index:]
x_four = history[1][3][start_index:]

c_one = history[2][0][start_index:]
c_two = history[2][1][start_index:]
c_three = history[2][2][start_index:]
c_four = history[2][3][start_index:]

noise_one = history[3][0][start_index:]
noise_two = history[3][1][start_index:]
noise_three = history[3][2][start_index:]
noise_four = history[3][3][start_index:]

ms = [m_one, m_two, m_three, m_four]
xs = [x_one, x_two, x_three, x_four]
cs = [c_one, x_two, c_three, c_four]
noises = [noise_one, noise_two, noise_three, noise_four]

# %% [markdown]
# ### Box Plots

# %%
def generate_box_plot(ax, data: List, color: str, label: str, position_offset: int = 0, showfliers: bool = False):
    ax.set_xlabel("Input Column and Node Number")
    ax.set_ylabel("Weight Values")
    color = {"color": color}
    ax.boxplot(
        data,
        positions=[i + position_offset for i in range(1,5)],
        boxprops=color,
        medianprops=color,
        whiskerprops=color,
        capprops=color,
        flierprops={"markeredgecolor": other},
        showfliers=showfliers,
        labels=[f"{label}{i}" for i in range(1,5)]
    )

# %%
fig, ax = plt.subplots(figsize=(16,6))

generate_box_plot(ax, ms, darker, "M")
generate_box_plot(ax, xs, important, "X", 4)
generate_box_plot(ax, cs, light, "C", 8)
generate_box_plot(ax, noises, noise, "Noise", 12)

# %%
fig, ax = plt.subplots(figsize=(16,6))

generate_box_plot(ax, ms, darker, "M", showfliers=True)
generate_box_plot(ax, xs, important, "X", 4, showfliers=True)
generate_box_plot(ax, cs, light, "C", 8, showfliers=True)
generate_box_plot(ax, noises, noise, "Noise", 12, showfliers=True)

# %% [markdown]
# ### Standard Deviation Etc.

# %%
data = {
    "m_one": m_one,
    "m_two": m_two,
    "m_three": m_three,
    "m_four": m_four,
    "x_one": x_one,
    "x_two": x_two,
    "x_three": x_three,
    "x_four": x_four,
    "c_one": c_one,
    "c_two": c_two,
    "c_three": c_three,
    "c_four": c_four,
    "noise_one": noise_one,
    "noise_two": noise_two,
    "noise_three": noise_three,
    "noise_four": noise_four
}

columns = [
    "m_one",
    "m_two",
    "m_three",
    "m_four",
    "x_one",
    "x_two",
    "x_three",
    "x_four",
    "c_one",
    "c_two",
    "c_three",
    "c_four",
    "noise_one",
    "noise_two",
    "noise_three",
    "noise_four"
]


odf = pd.DataFrame(data)
odf.head(5)
# Out:
#       m_one     m_two   m_three    m_four     x_one     x_two   x_three  \
# 0 -0.106060 -0.124091  0.638068  0.339750 -1.029656 -0.052108 -0.051184
# 1 -0.355130  0.030659  0.767380  0.155491 -1.281533  0.103834  0.078701
# 2 -0.408384  0.058394  0.790885  0.118401 -1.372918  0.149348  0.119627
# 3 -0.347041  0.031305  0.763658  0.160648 -1.370726  0.148562  0.118631
# 4 -0.294124  0.007757  0.741756  0.196896 -1.377669  0.151681  0.121436
#
#      x_four     c_one     c_two   c_three    c_four  noise_one  noise_two  \
# 0 -0.083654 -0.746815  0.054737  0.755206  0.181915  -1.055382  -0.043256
# 1 -0.269884 -0.995885  0.209487  0.884518 -0.002344  -1.292503   0.105598
# 2 -0.333702 -1.049139  0.237222  0.908023 -0.039434  -1.316409   0.119945
# 3 -0.332191 -0.987795  0.210133  0.880796  0.002813  -1.216164   0.075270
# 4 -0.336958 -0.934879  0.186585  0.858894  0.039061  -1.121460   0.032588
#
#    noise_three  noise_four
# 0     0.660921   -0.691673
# 1     0.785955   -0.868157
# 2     0.796447   -0.885089
# 3     0.751559   -0.815762
# 4     0.711792   -0.750358

# %%
m_one_std = odf["m_one"].agg([np.mean, np.std])
m_two_std = odf["m_two"].agg([np.mean, np.std])
m_three_std = odf["m_three"].agg([np.mean, np.std])
m_four_std = odf["m_four"].agg([np.mean, np.std])

noise_one_std = odf["noise_one"].agg([np.mean, np.std])
noise_two_std = odf["noise_two"].agg([np.mean, np.std])
noise_three_std = odf["noise_three"].agg([np.mean, np.std])
noise_four_std = odf["noise_four"].agg([np.mean, np.std])

# %%
std_df = odf.std().to_frame()
mean_df = odf.mean().to_frame()
std_df.columns = ["Std"]
mean_df.columns = ["Mean"]
merged_df = pd.merge(std_df, mean_df, left_index=True, right_index=True)

# %%
fig, ax = plt.subplots(figsize=(16,8))
ax.bar(
    [
      "M1", "M2", "M3", "M4", 
      "X1", "X2", "X3", "X4", 
      "C1", "C2", "C3", "C4", 
      "Noise 1", "Noise 2", "Noise 3", "Noise 4", 
    ],
    [
      std_df["Std"].loc["m_one"], std_df["Std"].loc["m_two"], std_df["Std"].loc["m_three"], std_df["Std"].loc["m_four"],
      std_df["Std"].loc["x_one"], std_df["Std"].loc["x_two"], std_df["Std"].loc["x_three"], std_df["Std"].loc["x_four"],
      std_df["Std"].loc["c_one"], std_df["Std"].loc["c_two"], std_df["Std"].loc["c_three"], std_df["Std"].loc["c_four"],
      std_df["Std"].loc["noise_one"], std_df["Std"].loc["noise_two"], std_df["Std"].loc["noise_three"], std_df["Std"].loc["noise_four"],
    ],
    color=[
      darker, darker, darker, darker,
      important, important, important, important,
      light, light, light, light,
      noise, noise, noise, noise
    ]
)
ax.set_xlabel("Input Column and Node Number")
ax.set_ylabel("Standard Deviation")
;
# Out:
# ''

# %%
g_ms = sum([std_df["Std"].loc["m_one"], std_df["Std"].loc["m_two"], std_df["Std"].loc["m_three"], std_df["Std"].loc["m_four"]])
g_xs = sum([std_df["Std"].loc["x_one"], std_df["Std"].loc["x_two"], std_df["Std"].loc["x_three"], std_df["Std"].loc["x_four"]])
g_cs = sum([std_df["Std"].loc["c_one"], std_df["Std"].loc["c_two"], std_df["Std"].loc["c_three"], std_df["Std"].loc["c_four"]])
g_noises = sum([std_df["Std"].loc["noise_one"], std_df["Std"].loc["noise_two"], std_df["Std"].loc["noise_three"], std_df["Std"].loc["noise_four"]])

# %%
fig, ax = plt.subplots(figsize=(16,8))
ax.bar(
    [
      "Ms", "Xs", "Cs", "Noises"
    ],
    [
      g_ms, g_xs, g_cs, g_noises
    ],
    color=[darker, important, light, noise]
)
;
# Out:
# ''

# %% [markdown]
# ### Scatter Plots

# %%
def prepare_scatter_df(data: List, bin: int, abs: bool = False):
    indices = [i for i in range(len(data))]
    df = pd.DataFrame(indices, columns=["Indices"])
    rdf = pd.DataFrame(data, columns=["Readings"])
    if abs:
        rdf = rdf.explode("Readings", ignore_index=True).abs()
    else:
        rdf = rdf.explode("Readings", ignore_index=True)
    df["Readings"] = rdf["Readings"]
    df["Bin"] = [bin for _ in range(len(data))]
    return df

# %%
def call_prepare_scatter_df(data: List, abs: bool = False):
    dfs = []
    for i, item in enumerate(data):
        dfs.append(prepare_scatter_df(item, i, abs))
    return pd.concat(dfs)

# %%
def create_scatter(scatter_dfs):
    fig, ax = plt.subplots(figsize=(16,6))
    ax.set_xlabel("Epoch")
    ax.set_ylabel("Weight")
    colormap = np.array([darker, important, light, noise])
    categories = np.array(scatter_dfs["Bin"])
    scatter = ax.scatter(x=scatter_dfs["Indices"], y=scatter_dfs["Readings"], c=colormap[categories], s=[2])

# %%
group_ones = [data["m_one"], data["x_one"], data["c_one"], data["noise_one"]]
sdf = call_prepare_scatter_df(group_ones, True)
create_scatter(sdf)

# %%
group_twos = [data["m_two"], data["x_two"], data["c_two"], data["noise_two"]]
sdf = call_prepare_scatter_df(group_twos, True)
create_scatter(sdf)

# %%
group_threes = [data["m_three"], data["x_three"], data["c_three"], data["noise_three"]]
sdf = call_prepare_scatter_df(group_threes, True)
create_scatter(sdf)

# %%
group_fours = [data["m_four"], data["x_four"], data["c_four"], data["noise_four"]]
sdf = call_prepare_scatter_df(group_fours, True)
create_scatter(sdf)

# %% [markdown]
# ### Plotting Standard Deviations

# %%
def plot_stds(group):
    fig, ax = plt.subplots(figsize=(16,6))
    domain = np.linspace(-2,2,1000)
    means = [mean(group[0]), mean(group[1]), mean(group[2]), mean(group[3])]
    stds = [stdev(group[0]), stdev(group[1]), stdev(group[2]), stdev(group[3])]
    colors = [darker, important, light, noise]

    for mu, std, color in zip(means, stds, colors):
        probs = norm.pdf(domain, mu, std)
        ax.plot(domain, probs, color=color)
        ax.set_xlabel("Weight")
        ax.set_ylabel("Probability Density")

# %%
plot_stds(group_ones)

# %%
plot_stds(group_twos)

# %%
plot_stds(group_threes)

# %%
plot_stds(group_fours)
